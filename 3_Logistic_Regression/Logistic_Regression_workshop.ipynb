# %%
import pandas as pd
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer

from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.linear_model import LogisticRegression

pd.options.mode.chained_assignment = None

# %%
# # Скачиваем датасет
# load_breast_cancer = load_breast_cancer()
# data  = pd.DataFrame(data = load_breast_cancer.data, columns = load_breast_cancer.feature_names)
# data['target'] = load_breast_cancer.target
# data

# %%
import seaborn as sns

# %% [markdown]
# https://github.com/allisonhorst/palmerpenguins

# %%
sns.load_dataset('penguins')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# **Preprocessing**
# 1. Удалите пропущенные значения или замените их средним/медианой в зависимости от вида (кроме пола).
# 2. Сделайте One-Hot Encoding острова.
# 3. Нормализуйте численные признаки при помощи `StandartScaler()`
#
# **Визуализация**
# 1. Постройте график длины клюва от длины плавников и покрасьте точки в завивисимости от вида.
# 2. Постройте матрицу корреляций для 4-х численных признаков.
#
# **Логистическая регрессия**
# 1. Примите Пингвина Adelie за класс 1, а другие виды за класс 0
# 2. Разделите данные на train/test в соотношении 70/30
# 3. Постройте логистическую регрессию в зависимости от island.
#     - Выведите коэффициенты логистической регрессии.
#     - Выведите логарифм шансов, что объект является пингвином Адели для каждого из островов.
#     - Выведите шансы, что объект является пингвином Адели для каждого из островов.
# 4. Постройте логистическую регрессию в зависимости от island и численных признаков.
#     - Выведите коэффициенты логистической регрессии.
#     - Отсортируйте коэффициенты по важности. Сделайте вывод о наиболее важных признаках.
#     - Замерьте качество на трейне и тесте: ROC AUC, с порогом 0.5: Accuracy, Sensitivity (Recall), Specifity, Precision.
#
# **Логистическая регрессия multi-class**
# 1. Постройте логистическую регрессию для всех трёх видов сразу (либо `multi_class='ovr'`, либо `multi_class='multinomial'`)
# 2. Измерьте качество на трейне и тесте:
#     - Выведите ROC AUC для каждого класса
#     - Выведите взвешенный ROC AUC

# %% [markdown]
# Можно попробовать дальше:
# 1. Ионосферный датасет https://archive.ics.uci.edu/ml/datasets/ionosphere
# 2. Винный датасет (12-класс-классификация) https://archive.ics.uci.edu/ml/datasets/wine <br>
#     ``from sklearn.datasets import load_wine``<br>
#     ``load_wine = load_wine()``<br>
#     ``data  = pd.DataFrame(data = load_wine.data, columns = load_wine.feature_names)``<br>
#     ``data['target'] = load_wine.target``
