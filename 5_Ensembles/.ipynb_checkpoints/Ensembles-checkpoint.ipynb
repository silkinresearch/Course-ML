# %% [markdown]
# https://scikit-learn.org/stable/datasets/toy_dataset.html#breast-cancer-dataset

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns

from sklearn.datasets import load_breast_cancer
import pandas as pd
breast_cancer = load_breast_cancer()

# %% [markdown]
# # Данные

# %%
breast_cancer_df = pd.DataFrame(data = breast_cancer.data, columns = breast_cancer.feature_names)
breast_cancer_df['is_benign'] = breast_cancer.target
breast_cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  is_benign
# 0                  0.2654          0.4601                  0.11890          0
# 1                  0.1860          0.2750                  0.08902          0
# 2                  0.2430          0.3613                  0.08758          0
# 3                  0.2575          0.6638                  0.17300          0
# 4                  0.1625          0.2364                  0.07678          0
# ..                    ...             ...                      ...        ...
# 564                0.2216          0.2060                  0.07115          0
# 565                0.1628          0.2572                  0.06637          0
# 566                0.1418          0.2218                  0.07820          0
# 567                0.2650          0.4087                  0.12400          0
# 568                0.0000          0.2871                  0.07039          1
#
# [569 rows x 31 columns]

# %% [markdown]
# - 212 - Malignant (0) (Доброкачественные)
# - 357 - Benign (1) (Злокачественные)

# %%
breast_cancer_df['is_benign'].value_counts()
# Out:
# 1    357
# 0    212
# Name: is_benign, dtype: int64

# %% [markdown]
# # Random Forest

# %% [markdown]
# как средство борьбы с переобучением

# %%
X = breast_cancer_df.drop(['is_benign'], axis = 1)
y = breast_cancer_df['is_benign']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
roc_aucs = {'train': [], 'test': [], 'test_forest': [], 'train_forest': [], 'cross_val_scores': []}
for depth in range(1, 50):
    # Инициализируем (сажаем) дерево решений
    clf_tree = DecisionTreeClassifier(criterion = 'entropy', max_depth=depth)
    clf_tree_for_cv = DecisionTreeClassifier(criterion = 'entropy', max_depth=depth)
    clf_forest = RandomForestClassifier(n_estimators=20, max_depth=depth)

    # Обучаем дерево решений
    clf_tree.fit(X_train, y_train)
    clf_forest.fit(X_train, y_train)
    
    mean_cross_val_score = cross_val_score(clf_tree_for_cv, X, y, scoring='roc_auc', cv = 5).mean()
    roc_aucs['test_forest'].append(roc_auc_score(y_true=y_test, y_score=clf_forest.predict_proba(X_test)[:, 1]))
    roc_aucs['train_forest'].append(roc_auc_score(y_true=y_train, y_score=clf_forest.predict_proba(X_train)[:, 1]))
    roc_aucs['train'].append(roc_auc_score(y_true=y_train, y_score=clf_tree.predict_proba(X_train)[:, 1]))
    roc_aucs['test'].append(roc_auc_score(y_true=y_test, y_score=clf_tree.predict_proba(X_test)[:, 1]))
    roc_aucs['cross_val_scores'].append(mean_cross_val_score)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
p=sns.lineplot(y=roc_aucs['train'], x=np.arange(1,50,1), label = 'Tree: Train', linestyle = '--')
p=sns.lineplot(y=roc_aucs['test'], x=np.arange(1,50,1), label = 'Tree: Test')
p=sns.lineplot(y=roc_aucs['test_forest'], x=np.arange(1,50,1), label = '*FOREST: Test')
p=sns.lineplot(y=roc_aucs['train_forest'], x=np.arange(1,50,1), label = '*FOREST: Train', linestyle = '--')
p=sns.lineplot(y=roc_aucs['cross_val_scores'], x=np.arange(1,50,1), label = 'Cross-Val: Tree')

p.set_xlabel('Глубина одного дерева', fontsize=12)
p.set_ylabel('ROC AUC', fontsize=12)

p.set_title('График зависимости ROC AUC от глубины дерева')
plt.suptitle('\n *Для случайного леса усредняются предсказания \n по 20 деревьям, построенным при данной глубине.', y=0, fontsize=10)

plt.show()

# %% [markdown]
# # GridSearchCV

# %%
# 1. Инициализация 
clf_rf = RandomForestClassifier()

# 2. Выбор параметров для GridSearchCV
parameters = {'max_depth': [5, 10, 20],
              'max_features': [3, 5, 7, 10]}   # максимальная глубина каждого дерева

# Инициализируем стэк классификаторов с параметрами из сетки parameters. 
grid_search_cv_clf = GridSearchCV(clf_rf, parameters, cv=5, scoring = 'roc_auc')

# 3. Обучение кучи моделей в GridSearchCV
grid_search_cv_clf.fit(X_train, y_train)
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 20, 'max_features': 7}

# %%
# Можно сразу получить лучшую модель
best_clf = grid_search_cv_clf.best_estimator_

# %%
result = pd.DataFrame(grid_search_cv_clf.cv_results_)[['param_max_depth', 'param_max_depth', 'mean_test_score', 'std_test_score', 'rank_test_score']].sort_values('rank_test_score')
result['mean_test_score'] = round(result['mean_test_score']*100, 2)
result['std_test_score'] = round(result['std_test_score']*100, 2)
result[:10]
# Out:
#    param_max_depth param_max_depth  mean_test_score  std_test_score  \
# 10              20              20            99.34            0.51
# 8               20              20            99.31            0.45
# 4               10              10            99.30            0.45
# 0                5               5            99.24            0.58
# 7               10              10            99.24            0.60
# 9               20              20            99.22            0.46
# 5               10              10            99.21            0.62
# 11              20              20            99.21            0.68
# 1                5               5            99.13            0.74
# 6               10              10            99.09            0.62
#
#     rank_test_score
# 10                1
# 8                 2
# 4                 3
# 0                 4
# 7                 5
# 9                 6
# 5                 7
# 11                8
# 1                 9
# 6                10

# %%
# Замеряем итоговое качество на трейне и тесте
round(roc_auc_score(y_score = best_clf.predict_proba(X_test)[:, 1], y_true=y_test)*100, 2)
# Out:
# 97.67

# %% [markdown]
# # GradientBoosting

# %%
# 1. Инициализация 
clf_rf = GradientBoostingClassifier()

# 2. Выбор параметров для GridSearchCV
parameters = {'max_features': [5, 10, 15], # количество деревьев
              'max_depth': [5, 7, 10, 12, 15]}   # максимальная глубина каждого дерева

# Инициализируем стэк классификаторов с параметрами из сетки parameters. 
grid_search_cv_clf = GridSearchCV(clf_rf, parameters, cv=5, scoring = 'roc_auc')

# 3. Обучение кучи моделей в GridSearchCV
grid_search_cv_clf.fit(X_train, y_train)
grid_search_cv_clf.best_params_
# Out:
# {'max_depth': 10, 'max_features': 5}

# %%
# Можно сразу получить лучшую модель
best_clf = grid_search_cv_clf.best_estimator_

# %%
# Замеряем итоговое качество на трейне и тесте
round(roc_auc_score(y_score = best_clf.predict_proba(X_test)[:, 1], y_true=y_test)*100, 2)
# Out:
# 98.58

# %% [markdown]
# # Feature Importance

# %% [markdown]
# # Random Forest Regressor
