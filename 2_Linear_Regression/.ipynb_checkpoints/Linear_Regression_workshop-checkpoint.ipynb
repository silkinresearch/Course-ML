# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
load_diabetes = load_diabetes(scaled=False)

# %% [markdown]
# https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset

# %%
data = pd.DataFrame(data=load_diabetes.data, columns=load_diabetes.feature_names)
data['disease_progress'] = load_diabetes.target
data
# Out:
#       age  sex   bmi      bp     s1     s2    s3    s4      s5     s6  \
# 0    59.0  2.0  32.1  101.00  157.0   93.2  38.0  4.00  4.8598   87.0
# 1    48.0  1.0  21.6   87.00  183.0  103.2  70.0  3.00  3.8918   69.0
# 2    72.0  2.0  30.5   93.00  156.0   93.6  41.0  4.00  4.6728   85.0
# 3    24.0  1.0  25.3   84.00  198.0  131.4  40.0  5.00  4.8903   89.0
# 4    50.0  1.0  23.0  101.00  192.0  125.4  52.0  4.00  4.2905   80.0
# ..    ...  ...   ...     ...    ...    ...   ...   ...     ...    ...
# 437  60.0  2.0  28.2  112.00  185.0  113.8  42.0  4.00  4.9836   93.0
# 438  47.0  2.0  24.9   75.00  225.0  166.0  42.0  5.00  4.4427  102.0
# 439  60.0  2.0  24.9   99.67  162.0  106.6  43.0  3.77  4.1271   95.0
# 440  36.0  1.0  30.0   95.00  201.0  125.2  42.0  4.79  5.1299   85.0
# 441  36.0  1.0  19.6   71.00  250.0  133.2  97.0  3.00  4.5951   92.0
#
#      disease_progress
# 0               151.0
# 1                75.0
# 2               141.0
# 3               206.0
# ...

# %% [markdown]
# - age age in years
# - sex
# - bmi body mass index
# - bp average blood pressure
# - s1 tc, total serum cholesterol
# - s2 ldl, low-density lipoproteins
# - s3 hdl, high-density lipoproteins
# - s4 tch, total cholesterol / HDL
# - s5 ltg, possibly log of serum triglycerides level
# - s6 glu, blood sugar level

# %%
X = data.drop(['disease_progress'], axis = 1)
corr_mtrx = X.corr()
mask = np.triu(np.ones(corr_mtrx.shape),0)
fig, ax = plt.subplots(figsize = (12,12))
ax = sns.heatmap(
    data = corr_mtrx,
    cmap='PuOr_r',
    center = 0,
    robust=True,
    annot = True,
    fmt = '.2f',
    square = True,
    linecolor='black',
    linewidths=2,
    cbar_kws = {'shrink': .85,
                'format': '%.2f'},
    mask = mask)

# %%
f, axes = plt.subplots(1, 3, figsize=(10,4))
sns.scatterplot(data = X, x = "s1", y = "s2", ax = axes[0])
sns.scatterplot(data = X, x = "s3", y = "s4", ax = axes[1])
sns.scatterplot(data = X, x = "s2", y = "s4", ax = axes[2])
plt.show()

# %% [markdown]
# # Задание

# %% [markdown]
# 1. Разделите данные на train и test в соотношении 0.7 на 0.3.
# 2. Стандартизируйте признаки (кроме номинативных) на трейне и тесте при помощи StandartScaler().
# 3. Обучите модель и выведите коэффициенты. Отсортируйте признаки по размеру коэффициентов.
# 4. Выведите метрики модели на train и test: MAE, R
# 5. Выведите MAE для случайного регрессора (который предсказывает среднее).
# 6. Выведите тепловую карту корреляций между признаками.
# 7. Повторите анализ, удалив скоррелированные фичи. Отсортируйте признаки по размеру коэффициентов. Снимите метрики.
# 8. Повторите анализ, удалив неважные фичи. Снимите метрики.
